# %%
import pandas as pd
df = pd.read_csv('../data/train.csv')

# %%
df.drop(['team_name','confederation'],axis=1,inplace=True)

# %%
df[df.duplicated()].shape
# Out:
# (0, 25)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [team_name, country_code, confederation, fifa_rank, fifa_points, wins_last_10_matches, losses_last_10_matches, draws_last_10_matches, win_rate_last_year, goals_scored_avg, goals_conceded_avg, clean_sheets_last_10, shots_per_game, shots_on_target_ratio, avg_player_rating, star_players_count, market_value_million_eur, experience_avg_caps, coach_experience_years, recent_form_score, possession_avg, passing_accuracy, host_advantage, travel_distance_avg, climate_similarity_score]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ENG - country_code already represents the classifictation, so I judged these two columns as unecessary

# %% [markdown]
# PTBR - Como o código do país representa o mesmo que team_name, e tem menos letras, acho que utilizar apenas country_code já é o suficiente.

# %%
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# ENG  - No null data, so no fit.

# %% [markdown]
# PTBR - Sem nulos, então sem preenchimento de dados nulos.

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()

# %%
df = pd.get_dummies(df, columns=['country_code'])

# %%
df.head()
# Out:
#    fifa_rank  fifa_points  wins_last_10_matches  losses_last_10_matches  \
# 0         18       1675.2                     5                       4
# 1          8       1831.2                     7                       2
# 2          6       1769.3                     6                       2
# 3         17       1663.4                     7                       1
# 4         28       1476.6                     3                       5
#
#    draws_last_10_matches  win_rate_last_year  goals_scored_avg  \
# 0                      1               0.520              1.11
# 1                      1               0.690              2.31
# 2                      2               0.585              1.85
# 3                      2               0.584              1.40
# 4                      2               0.390              0.95
#
#    goals_conceded_avg  clean_sheets_last_10  shots_per_game  ...  \
# 0                0.91                     3            11.3  ...
# ...

# %%
df['winner'].value_counts()
# Out:
# winner
# 0    527
# 1    473
# Name: count, dtype: int64

# %% [markdown]
# ENG - Seems even

# %% [markdown]
# PTBR - Parece balanceado.

# %%
X = df.drop(columns=['winner'])

# %%
y = df['winner']

# %%
df.head()
# Out:
#    fifa_rank  fifa_points  wins_last_10_matches  losses_last_10_matches  \
# 0         18       1675.2                     5                       4
# 1          8       1831.2                     7                       2
# 2          6       1769.3                     6                       2
# 3         17       1663.4                     7                       1
# 4         28       1476.6                     3                       5
#
#    draws_last_10_matches  win_rate_last_year  goals_scored_avg  \
# 0                      1               0.520              1.11
# 1                      1               0.690              2.31
# 2                      2               0.585              1.85
# 3                      2               0.584              1.40
# 4                      2               0.390              0.95
#
#    goals_conceded_avg  clean_sheets_last_10  shots_per_game  ...  \
# 0                0.91                     3            11.3  ...
# ...

# %%
print(X)
# Out:
#      fifa_rank  fifa_points  wins_last_10_matches  losses_last_10_matches  \
# 0           18       1675.2                     5                       4
# 1            8       1831.2                     7                       2
# 2            6       1769.3                     6                       2
# 3           17       1663.4                     7                       1
# 4           28       1476.6                     3                       5
# ..         ...          ...                   ...                     ...
# 995          2       1973.5                     8                       0
# 996          5       1675.4                     6                       3
# 997         30       1713.1                     5                       2
# 998         48       1433.8                     1                       6
# 999         40       1463.2                     3                       7
#
#      draws_last_10_matches  win_rate_last_year  goals_scored_avg  \
# ...

# %%
print(y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 995    0
# 996    1
# 997    0
# 998    0
# 999    0
# Name: winner, Length: 1000, dtype: int64

# %% [markdown]
# ENG - y as our target

# %% [markdown]
# PTBR - Definindo alvo

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
df2 = pd.read_csv('../data/test.csv')

# %%
df2.head()
# Out:
#    team_name country_code confederation  fifa_rank  fifa_points  \
# 0  Argentina          ARG      CONMEBOL          6       1784.8
# 1    Ecuador          ECU      CONMEBOL         23       1669.3
# 2    Morocco          MAR           CAF         21       1714.0
# 3      China          CHN           AFC         35       1531.5
# 4    Croatia          CRO          UEFA         12       1697.9
#
#    wins_last_10_matches  losses_last_10_matches  draws_last_10_matches  \
# 0                     6                       2                      2
# 1                     6                       4                      0
# 2                     4                       5                      1
# 3                     2                       6                      2
# 4                     7                       2                      1
#
#    win_rate_last_year  goals_scored_avg  ...  star_players_count  \
# 0               0.747              2.18  ...                   5
# ...

# %%
df2['team_name'].value_counts()
# Out:
# team_name
# France          16
# Argentina       12
# England         12
# Brazil          11
# USA              9
# Senegal          9
# Croatia          8
# Spain            8
# Germany          8
# Colombia         7
# Italy            7
# Wales            7
# Serbia           7
# Austria          6
# Poland           6
# Portugal         6
# Sweden           6
# Cameroon         6
# Japan            6
# Netherlands      6
# Australia        5
# Tunisia          5
# Egypt            5
# Jamaica          5
# Belgium          5
# Ecuador          4
# Turkey           4
# Ukraine          4
# South Korea      4
# Iran             4
# Denmark          4
# Ghana            4
# Uruguay          4
# Costa Rica       4
# Morocco          3
# Mexico           3
# Qatar            3
# China            2
# Saudi Arabia     2
# Nigeria          2
# Switzerland      2
# New Zealand      2
# Paraguay         2
# Canada           2
# Peru             1
# Algeria          1
# Honduras         1
# ...

# %%
df2[df2.duplicated()].shape
# Out:
# (0, 25)

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [team_name, country_code, confederation, fifa_rank, fifa_points, wins_last_10_matches, losses_last_10_matches, draws_last_10_matches, win_rate_last_year, goals_scored_avg, goals_conceded_avg, clean_sheets_last_10, shots_per_game, shots_on_target_ratio, avg_player_rating, star_players_count, market_value_million_eur, experience_avg_caps, coach_experience_years, recent_form_score, possession_avg, passing_accuracy, host_advantage, travel_distance_avg, climate_similarity_score]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.head()
# Out:
#    team_name country_code confederation  fifa_rank  fifa_points  \
# 0  Argentina          ARG      CONMEBOL          6       1784.8
# 1    Ecuador          ECU      CONMEBOL         23       1669.3
# 2    Morocco          MAR           CAF         21       1714.0
# 3      China          CHN           AFC         35       1531.5
# 4    Croatia          CRO          UEFA         12       1697.9
#
#    wins_last_10_matches  losses_last_10_matches  draws_last_10_matches  \
# 0                     6                       2                      2
# 1                     6                       4                      0
# 2                     4                       5                      1
# 3                     2                       6                      2
# 4                     7                       2                      1
#
#    win_rate_last_year  goals_scored_avg  ...  star_players_count  \
# 0               0.747              2.18  ...                   5
# ...

# %%
df['country_code'].value_counts().sum()
# Out:
# np.int64(250)

# %%
df2['country_code'].value_counts().sum()
# Out:
# np.int64(250)

# %%
print(df['country_code'].nunique())
# Out:
# 47

# %%
print(df2['country_code'].nunique())
# Out:
# 47
