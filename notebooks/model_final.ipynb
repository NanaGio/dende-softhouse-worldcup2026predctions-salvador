# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: numpy in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: scikit-learn in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2026.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\joaom\desktop\unex\2026\2026.1\matérias\mineração de dados\dende-softhouse-worldcup2026predctions-salvador\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
import os
import sys
import pandas as pd

base_dir = os.path.abspath('..')
sys.path.append(os.path.join(base_dir, 'src'))

from dende_train import load_and_split_data, train_models

train_data_path = os.path.join(base_dir, 'data', 'train_engineered.csv')
test_data_path = os.path.join(base_dir, 'data', 'test_engineered.csv')
test_original_path = os.path.join(base_dir, 'data', 'test.csv')

X_train, X_test, y_train, y_test = load_and_split_data(train_data_path)
trained_models = train_models(X_train, y_train)

# Nota: Mude para 'Logistic Regression' se quiser o resultado exato do slide 20
best_model = trained_models['Random Forest (Tuning)'] 

df_test_features = pd.read_csv(test_data_path)
df_test_original = pd.read_csv(test_original_path)

missing_cols = set(X_train.columns) - set(df_test_features.columns)
for c in missing_cols:
    df_test_features[c] = 0

df_test_features = df_test_features[X_train.columns]

win_probabilities = best_model.predict_proba(df_test_features)[:, 1]

results_df = pd.DataFrame({
    'Team': df_test_original['team_name'],
    'Win_Probability_Percentage': win_probabilities * 100
})

team_avg_prob = results_df.groupby('Team', as_index=False)['Win_Probability_Percentage'].mean()
ranking = team_avg_prob.sort_values(by='Win_Probability_Percentage', ascending=False).reset_index(drop=True)

print("\n" + "-"*50)
print(" ★ RANKING DE PROBABILIDADE MÉDIA DE VENCER A COPA ★")
print(ranking.head(10)) 

champion = ranking.iloc[0]['Team']
print("\n" + "★" * 20)
print(f"\n VENCEDOR : ★ {champion.upper()} ★ \n")
print("\n" + "★" * 20)
# Out:
# Carregando dados de C:\Users\joaom\Desktop\UNEX\2026\2026.1\Matérias\Mineração de Dados\dende-softhouse-worldcup2026predctions-salvador\data\train_engineered.csv...
# Separando a base de dados (test_size=0.2)...
# Tamanho do conjunto de treino: 800 amostras
# Tamanho do conjunto de teste: 200 amostras
#
# Iniciando o treinamento dos modelos...
# Treinando Random Forest (Default)...
# Random Forest (Default) treinado com sucesso.
# Treinando Random Forest (Tuning)...
# Random Forest (Tuning) treinado com sucesso.
# Treinando Logistic Regression...
# Logistic Regression treinado com sucesso.
#
# --------------------------------------------------
#  ★ RANKING DE PROBABILIDADE MÉDIA DE VENCER A COPA ★
#           Team  Win_Probability_Percentage
# 0       France                   77.233151
# 1    Argentina                   75.071151
# 2      England                   74.096088
# 3       Brazil                   73.482641
# 4        Spain                   73.345508
# 5      Croatia                   58.235383
# 6        Italy                   57.059753
# 7      Uruguay                   55.415631
# 8     Colombia                   55.021842
# 9  Netherlands                   53.794855
#
# ★★★★★★★★★★★★★★★★★★★★
#
#  VENCEDOR : ★ FRANCE ★
#
#
# ★★★★★★★★★★★★★★★★★★★★
